# %%
import integrate_omics as integrate
from cobra.io import read_sbml_model

# %%
model = read_sbml_model('iCHO2441.xml')
# %store -r transcriptomics
cho_objective = {model.reactions.get_by_id('biomass_cho_prod'):0.5,model.reactions.get_by_id('ICproduct_TRANSLATION_protein'):0.5}

# %%
# Example use
# Set parameters
B13_D6_1 = transcriptomics[['B13_D6_1']]
cho_objective = {model.reactions.get_by_id('biomass_cho_prod'):0.5,model.reactions.get_by_id('ICproduct_TRANSLATION_protein'):0.5}

# Run integrate_omics
B13_D6_1_test = integrate.integrate_omics('iCHO2441.xml', 'biomass_cho_prod', cho_objective, 0.01, B13_D6_1)
